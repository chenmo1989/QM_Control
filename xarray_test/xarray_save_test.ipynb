# %% [markdown]
# # Test the to_netCDF() save function of xarray, when it's passed through functions

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
import datetime
from matplotlib import pyplot as plt

# %%
from DataLoggingTest import DataLoggingHandle

# %%
# creating a dataset
temp = 15 + 8 * np.random.randn(2, 2, 3)
precip = 10 * np.random.rand(2, 2, 3)
lon = [[-99.83, -99.32], [-99.79, -99.23]]
lat = [[42.25, 42.21], [42.63, 42.59]]

# for real use cases, its good practice to supply array attributes such as
# units, but we won't bother here for the sake of brevity
ds = xr.Dataset(
    {
        "temperature": (["x", "y", "time"], temp),
        "precipitation": (["x", "y", "time"], precip),
    },
    coords={
        "lon": (["x", "y"], lon),
        "lat": (["x", "y"], lat),
        "time": pd.date_range("2014-09-06", periods=3),
        "reference_time": pd.Timestamp("2014-09-05"),
    },
)

# %%
DL = DataLoggingHandle()

# %%
ds.close()
DL.save(ds, "save_test")
# Out:
# /Users/chenmo/Documents/GitHub/QM_control/xarray_test/2024/05/Data_0504/
# 0
# /Users/chenmo/Documents/GitHub/QM_control/xarray_test/2024/05/Data_0504/2024-05-04_save_test
# ----------saved to /Users/chenmo/Documents/GitHub/QM_control/xarray_test/2024/05/Data_0504/2024-05-04_save_test
# <xarray.Dataset> Size: 288B
# Dimensions:         (x: 2, y: 2, time: 3)
# Coordinates:
#     lon             (x, y) float64 32B -99.83 -99.32 -99.79 -99.23
#     lat             (x, y) float64 32B 42.25 42.21 42.63 42.59
#   * time            (time) datetime64[ns] 24B 2014-09-06 2014-09-07 2014-09-08
#     reference_time  datetime64[ns] 8B 2014-09-05
# Dimensions without coordinates: x, y
# Data variables:
#     temperature     (x, y, time) float64 96B 16.07 9.314 11.25 ... 28.45 6.186
#     precipitation   (x, y, time) float64 96B 4.386 7.361 5.723 ... 5.123 3.407
# Attributes:
#     name:       save_test
#     directory:  /Users/chenmo/Documents/GitHub/QM_control/xarray_test/2024/05...
