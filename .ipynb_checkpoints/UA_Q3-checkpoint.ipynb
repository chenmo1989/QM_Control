# %% [markdown]
# # Basic characterizations of UA Q3
# ### using Experiment and Analysis classes

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qm.octave import QmOctaveConfig
from quam import QuAM

from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
#from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber
import xarray as xr

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 0 # for UA Q3
TLS_index = 0 # for TLS of interest
dc_flux_index = 2 # for dc line
# Out:
# 2024-06-24 16:50:39,075 - qm - INFO     - Starting session: 63274482-23fe-4c5d-a867-fc8d62115fe1

# %%
Analysis = AnalysisHandle("quam_state_q2.json")
machine = Analysis.get_machine()
Experiment = ExperimentHandle(machine)

# %%
# Set voltage of flux line to 0 V
for i in np.arange(7): 
    machine.dc_flux[i].dc_voltage = 0 + 0E6
machine = Analysis.set_machine(machine)

# %%
# initialize Labber-controlled hardware
# get values from QDAC first
#machine = Experiment.set_Labber.get_value_from_QDAC(machine)
# set all Labber settings
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
# set octave to external clock
#Experiment.set_octave.set_clock(machine)

# %%
# set to qubit
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)

# %%
machine.octaves[0].LO_sources[1].gain = 0
machine = Analysis.set_machine(machine)

# %%
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.100 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.053 GHz, -49.671 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # Qubit Readout

# %% [markdown]
# ## Time of Flight

# %%
# time_of_flight
# experiment
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.time_of_flight(machine,qubit_index, n_avg = 10E3, cd_time = 10E3, to_simulate = False, simulation_len = 1000)
# plot
# %matplotlib inline
dc_offset_i, dc_offset_q, delay = Analysis.exp1D.time_of_flight(expt_dataset)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 66.35s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_time_of_flight_3
# DC offset to add to I: 0.000174 V
# DC offset to add to Q: 0.000272 V
# TOF to add: 4.0 ns

# %%
# update the offset
machine.global_parameters.downconversion_offset_I[0] += dc_offset_i
machine.global_parameters.downconversion_offset_Q[0] += dc_offset_q
machine.resonators[qubit_index].downconversion_offset_I = machine.global_parameters.downconversion_offset_I[0]
machine.resonators[qubit_index].downconversion_offset_Q = machine.global_parameters.downconversion_offset_Q[0]
#machine.global_parameters.time_of_flight = 304-0
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## Resonator spectroscopy

# %% [markdown]
# ### 1D resonator spectroscopy

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.45

# %%
# %matplotlib qt
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-5E6,5E6 + 1.0,0.05E6)
machine, expt_dataset = Experiment.exp1D.RR.rr_freq(machine, res_freq_sweep, qubit_index, n_avg = 5E3, cd_time = 10E3, live_plot = True,
                                                    readout_state = 'g', to_simulate = False, data_process_method = 'Amplitude')
# Readout in excited state
# machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
#                           n_avg = 1E3, cd_time = 5E3, readout_state = 'e', simulate_flag = False, simulation_len = 1000)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 11.16s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_res_spec
# Execution stopped by user!

# %%
# find the minimal
# %matplotlib inline
res_freq = Analysis.exp1D.rr_freq(expt_dataset)
machine.resonators[qubit_index].f_readout = res_freq + 0E6
# Out:
# resonator frequency: 7003.929 MHz

# %%
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.100 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### 2D resonator spectroscopy

# %%
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-6e6, 4e6, 0.1E6)
dc_flux_sweep = np.arange(-9,9.001,0.1)
# %matplotlib qt
machine, expt_dataset = Experiment.exp2D.RR.rr_vs_dc_flux(machine, res_freq_sweep, dc_flux_sweep, qubit_index,
                                                          n_avg = 1E3, cd_time = 10E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=181/181) --> elapsed time: 353.79s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0604\2024-06-04_q2_res_spec2D

# %%
# %matplotlib inline 
ham_param = Analysis.exp2D.rr_vs_dc_flux(expt_dataset, to_plot = True, init_guess = None)
poly_param = Analysis.exp2D.qubit_vs_dc_flux_guess(ham_param = ham_param, to_plot = True)
# Out:
# Execution stopped by user!

# %%
# save the fitting parameters
machine.resonators[qubit_index].tuning_curve = ham_param
machine.qubits[qubit_index].DC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %%
# save the sweep spot flux according to fitted parameter
machine.dc_flux[dc_flux_index].max_frequency_point = Analysis.get_sweept_spot(poly_param)
machine = Analysis.set_machine(machine)

# %% [markdown]
# if 2D res spectroscopy is just to test the experiment, and I want to go back to sweet spot

# %%
machine = Analysis.update_machine_res_frequency_sweet_spot(machine, qubit_index, dc_flux_index) 
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50e6
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.100 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.053 GHz, -49.671 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # Qubit Sweet Spot Calibrations

# %% [markdown]
# ## 1D qubit spectroscopy @ sweep spot

# %%
if True: # for the DC flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].DC_tuning_curve,machine.dc_flux[dc_flux_index].max_frequency_point) * 1E6 # in Hz
else: # for the fast flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,0.0) * 1E6 # in Hz

qubit_freq_sweep = int(qubit_freq_est) + np.arange(-30E6, 30E6 + 1, 0.5E6)
    
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.Rabi.qubit_freq(machine, qubit_freq_sweep, qubit_index, pi_amp_rel = 1.0, live_plot = True,
                                                         ff_amp = 0.0, n_avg = 1E4, cd_time = 30E3, to_simulate = False, data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 38.32s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_spec_2

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'Amplitude')
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
# Out:
# peak frequency:  6052.8 [MHz]

# %%
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.103 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.054 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ## Rabi

# %% [markdown]
# ### Time Rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 240 + 0.1, 4)  # in ns
machine, expt_dataset = Experiment.exp1D.Rabi.rabi_length(machine, rabi_duration_sweep, qubit_index, pi_amp_rel = 1.0, live_plot = True, 
                                                          n_avg = 10E3, cd_time = 25E3, to_simulate = False, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 15.24s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_time_rabi_2

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", to_plot = True, data_process_method = 'Amplitude')
# Out:
# rabi_pi_pulse: 100.2 [ns]
# pi period: 98.90 [ns]

# %%
machine.qubits[qubit_index].pi_length = 100
# machine.qubits[qubit_index].pi_amp[0] = 0.0270983
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.1, 2.0, 0.05) 
machine, expt_dataset = Experiment.exp1D.Rabi.rabi_amp(machine, rabi_amp_sweep_rel, qubit_index, ff_amp = 0.0, live_plot = True,
                                       n_avg = 5E4, cd_time = 20E3, data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=50000/50000.0) --> elapsed time: 41.08s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_power_rabi_2

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", data_process_method = 'Amplitude')
machine.qubits[qubit_index].pi_amp = pi_pulse_amp
machine = Analysis.set_machine(machine)
# Out:
# rabi_pi_amp: 0.026 [V]
# pi period: 0.026 [V]

# %% [markdown]
# ## Single-Shot Readout

# %% [markdown]
# ### Find frequency between g, e

# %%
# %matplotlib qt
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-4E6,4E6 + 1.0,0.05E6)
machine, expt_dataset = Experiment.exp1D.RR.rr_freq_ge(machine, res_freq_sweep, qubit_index, n_avg = 1E4, cd_time = 10E3,
                                                    to_simulate = False, simulation_len = 1000, live_plot = True, data_process_method = 'Phase')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 36.23s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_res_spec_ge

# %%
# %matplotlib inline
res_freq_phase = Analysis.exp1D.rr_freq_ge(expt_dataset)
# Out:
# resonator frequency: 7003.079 MHz
# Execution stopped by user!

# %%
# doesn't have to update. Use res_freq_phase
# machine.resonators[qubit_index].f_readout = 6226119034 + 0E6
machine.resonators[qubit_index].f_readout = res_freq_phase + 0E6
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.103 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.053 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### IQ blobs

# %%
# %matplotlib inline
machine, expt_dataset = Experiment.exp1D.RR.single_shot_IQ_blob(machine, qubit_index, n_avg = 30E3, cd_time = 25E3, final_plot = False)
# Out:
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_single_shot_IQ_10-> elapsed time: 1.60s

# %%
# %matplotlib inline
angle, threshold, fidelity, gg, ge, eg, ee = Analysis.exp1D.two_state_discriminator(expt_dataset)
# Out:
# 			Fidelity Matrix:
# 			-----------------
# 			| 0.937 | 0.063 |
# 			----------------
# 			| 0.145 | 0.855 |
# 			-----------------
# 			IQ plane rotated by: 0.7°
# 			Threshold: -5.165e-04
# 			Fidelity: 89.6%

# %%
# set the rotation angle
machine.resonators[qubit_index].rotation_angle -= angle # note this is the change value not the absolute value!
machine.resonators[qubit_index].ge_threshold = threshold
machine = Analysis.set_machine(machine)

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.47
machine.resonators[qubit_index].readout_pulse_length = 1080
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout freq optimization

# %%
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-1.5E6, 1.5E6 + 1, 0.05E6)

# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_freq_optimization(machine, res_freq_sweep, qubit_index, n_avg = 5E4, cd_time = 25E3, 
                                                           final_plot = True, live_plot = True)
# Out:
# Execution stopped by user!                                   ] 11.9% (n=5926/50000.0) --> elapsed time: 19.01s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0522\2024-05-22_q4_single_shot_freq.0) --> elapsed time: 19.27s
# The optimal readout frequency is 6223722880.0 Hz (SNR=0.048823998479026236)

# %%
# %matplotlib inline
res_freq = Analysis.exp1D.peak_fit(expt_dataset,method="Gaussian", data_process_method = 'SNR')
# Out:
# peak frequency:  6226.2 [MHz]
# Execution stopped by user!

# %%
machine.resonators[qubit_index].f_readout = res_freq + 0E6
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q4 for (LO, IF) = (5.762 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r4 for (LO, IF) = (6.274 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### Readout pulse amp and duration (by qubit relaxation during readout)

# %%
# %matplotlib qt
res_duration_sweep_abs = np.arange(300, 2000 + 1, 20)
res_amp_sweep_abs = np.arange(0.15,0.45,0.001)
machine, expt_dataset = Experiment.exp2D.RR.rr_pulse_optimize(machine, res_duration_sweep_abs, res_amp_sweep_abs, qubit_index, n_avg=1E3, 
                                                              cd_time=25E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 744.49s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q4_res_pulse_optimize

# %%
# %matplotlib inline
data = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q4_res_pulse_optimize.nc")
data['I'].plot(x = list(expt_dataset.coords.keys())[0], y = list(expt_dataset.coords.keys())[1], cmap = "seismic")

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.45
machine.resonators[qubit_index].readout_pulse_length =1396
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout duration optimization

# %%
division_length = 40
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_duration_optimization(machine, division_length, qubit_index,
                                                                    readout_len = 2000, n_avg = 2E4, cd_time = 25E3)
# Out:
# Integration weights chunk-size length in ns: 40
# The readout has been sliced in the following number of divisions 50
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.72s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.73s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.75s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.77s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.78s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.80s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.81s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.83s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.84s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.86s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.87s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.88s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.89s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.91s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.92s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.94s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.95s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.97s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.98s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.00s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.01s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.30s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.32s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0522\2024-05-22_q4_single_shot_len
# The optimal readout duration is 200 ns (Fidelity=53.1%)

# %%
machine.resonators[qubit_index].readout_pulse_length = 1360
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout amp optimization

# %%
res_amp_sweep = np.arange(0.5,1.5 + 1E-4, 0.01)

# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_amp_optimization(machine, res_amp_sweep, qubit_index,
                              n_avg = 5E3, cd_time = 25E3, final_plot= True)
# Out:
# some abs amps > 0.5, removed from experiment run
# 2024-05-21 16:17:16,725 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,749 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,773 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,795 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,817 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,839 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,864 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,891 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,917 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,941 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,964 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:16,987 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,010 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,032 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,051 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,073 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,091 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,113 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,132 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,150 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,170 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,191 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,217 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,243 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,268 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,295 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.04s
# 2024-05-21 16:17:17,321 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.07s
# 2024-05-21 16:17:17,348 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.10s
# 2024-05-21 16:17:17,376 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.13s
# 2024-05-21 16:17:17,401 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.15s
# 2024-05-21 16:17:17,429 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.18s
# 2024-05-21 16:17:17,456 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.21s
# 2024-05-21 16:17:17,483 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.23s
# 2024-05-21 16:17:17,508 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.26s
# 2024-05-21 16:17:17,535 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.29s
# 2024-05-21 16:17:17,574 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.32s
# 2024-05-21 16:17:17,592 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.34s
# 2024-05-21 16:17:17,610 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.44s
# 2024-05-21 16:17:17,710 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# Progress: [##################################################] 100.0% (n=62/62) --> elapsed time: 16.46s
# 2024-05-21 16:17:17,772 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,860 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,925 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-05-21 16:17:17,998 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q4_single_shot_amp
# The optimal readout amplitude is 454.500 mV (Fidelity=65.8%)

# %%
# %matplotlib inline
readout_amp = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'Fidelity')
# Out:
# peak voltage:  0.484 [V]

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.48
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## Qubit T1

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(100,30E3+1,1E3)
machine, expt_dataset = Experiment.exp1D.T1.qubit_T1(machine, tau_sweep_abs, qubit_index, n_avg = 1E4, cd_time = 40E3, live_plot = True,
                                                               to_simulate = False, simulation_len = 15_000, data_process_method = 'I')
# Out:
# Execution stopped by user!#################                  ] 64.2% (n=6422/10000.0) --> elapsed time: 10.57s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0604\2024-06-04_q2_T1 (n=6606/10000.0) --> elapsed time: 11.50s

# %%
# %matplotlib inline
qubit_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
machine.qubits[qubit_index].T1 = qubit_T1
machine = Analysis.set_machine(machine)
# Out:
# Qubit T1: 3.9 [us]

# %% [markdown]
# ## Qubit Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(16, 10000 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Ramsey.ramsey(machine, ramsey_duration_sweep, qubit_index, detuning = 2E6, live_plot = True,
                                                       n_avg = 2E4, cd_time = 20E3, to_simulate = False, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 263.82s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_ramsey_3

# %%
# %matplotlib inline
q_T2star = Analysis.exp1D.ramsey(expt_dataset, data_process_method = 'I')
machine.qubits[qubit_index].T2 = q_T2star
machine = Analysis.set_machine(machine)
# Out:
# Qubit T2*:  1125.8 [ns]
# Exponent n =  0.7
# Detuning =  2.0 [MHz]

# %%
# %matplotlib inline
fft_dataset = Analysis.exp1D.fft(expt_dataset, to_plot = True, data_process_method = 'I')

# %%
# Get the peak frequency
idx = fft_dataset['FFT_Result'].argmax().item()
max_freq = fft_dataset['FFT_Frequency'][idx].item()
max_freq
# Out:
# 1956947.1624266144

# %% [markdown]
# ## ef transition

# %% [markdown]
# ### ef frequency

# %%
# %matplotlib qt
ef_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-190E6, -150E6 + 1, 0.5E6) 
machine, expt_dataset = Experiment.exp1D.Rabi.ef_freq(machine, ef_freq_sweep, qubit_index, pi_amp_rel_ef = 1.0, n_avg = 2E3, live_plot = True,
                                                      cd_time = 30E3, readout_state = 'g', to_simulate = False, data_process_method = 'I')

# %%
# %matplotlib inline
ef_freq = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'I')

# %%
machine.qubits[qubit_index].anharmonicity = machine.qubits[qubit_index].f_01 - ef_freq
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition time Rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 240 + 0.1, 4)  # in ns
rabi_duration_sweep = rabi_duration_sweep.astype(int)
machine, expt_dataset = Experiment.exp1D.Rabi.ef_rabi_length(machine, rabi_duration_sweep, qubit_index, pi_amp_rel_ef = 1.0, live_plot = True,
                                                                             n_avg = 2E3, cd_time = 30E3, readout_state = 'g', 
                                                                             to_simulate = False, simulation_len = 10_000, data_process_method = 'I')

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, data_process_method = 'I')

# %%
machine.qubits[qubit_index].pi_length_ef = 180
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.2, 2.0, 0.025) 
machine, expt_dataset = Experiment.exp1D.Rabi.ef_rabi_amp(machine, rabi_amp_sweep_rel, qubit_index, n_avg = 2E3, cd_time = 30E3, live_plot = True,
                                                          readout_state = 'g', to_simulate = False, simulation_len = 1000, data_process_method = 'I')

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", data_process_method = 'I')

# %%
machine.qubits[qubit_index].pi_amp_ef = pi_pulse_amp
machine = Analysis.set_machine(machine)

# %% [markdown]
# # Qubit Tuning Curves

# %% [markdown]
# ## 2D qubit spectroscopy vs dc flux

# %%
# try the experiment
# %matplotlib qt
dc_flux_sweep = machine.dc_flux[dc_flux_index].max_frequency_point + np.arange(-0.45,0.45+1E-4,0.02)
qubit_if_sweep = np.arange(-30E6, 30E6, 1E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_dc_flux(machine, dc_flux_sweep, qubit_if_sweep, qubit_index,
                                 n_avg = 1E3, cd_time = 20E3, final_plot = True, live_plot = True,  data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=46/46) --> elapsed time: 475.95s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_res_spec_vs_dc_flux_2
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_qubit_spec_vs_dc_flux_2

# %%
# udpate the sweet spot
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 2, to_plot = False, data_process_method = 'Amplitude')
machine.dc_flux[dc_flux_index].max_frequency_point = Analysis.get_sweept_spot(poly_param) + 0E1
print(f"sweet spot flux: {machine.dc_flux[dc_flux_index].max_frequency_point:.5f} V")
# Out:
# sweet spot flux: -0.79486 V

# %%
# save the sweep spot flux according to fitted parameter
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True, data_process_method = 'Amplitude')
machine.qubits[qubit_index].DC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %%
# go to the sweet spot, if needed
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)

# %%
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.103 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.053 GHz, -49.578 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ## 2D qubit spectroscopy vs fast flux

# %%
# set DC voltage to sweet spot, after possible dc flux sweep
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### slow version, compiling 1D scans

# %%
# try the experiment
# %matplotlib qt
#ff_sweep = np.arange(-0.02,-0.28-1E-4,-0.02)
ff_sweep = np.arange(0,0.25+1E-4,0.05)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 1E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux_slow(machine, ff_sweep,qubit_if_sweep,
      qubit_index, ff_to_dc_ratio = None, n_avg = 1E3, cd_time = 20E3)
# Out:
# Execution stopped by user!
# ------------------------------------- Octave calibration starts...7% (n=4/6) --> elapsed time: 19.81s
# ------------------------------------- Calibrates q2 for (LO, IF) = (5.496 GHz,  290.000 MHz)
# 2024-06-24 17:39:56,569 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,687 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,709 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,740 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,756 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,778 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:39:56,801 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=6/6) --> elapsed time: 38.52s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_qubit_spec_vs_fast_flux

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True, data_process_method = 'I')
machine.qubits[qubit_index].AC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### fast version, runs blockwise 2D sweeps

# %%
# %matplotlib qt
q_freq_max = np.floor(np.polyval(machine.qubits[qubit_index].AC_tuning_curve, 0.0) * 1E6)
qubit_freq_sweep = np.arange(q_freq_max, 4.4E9, -5E6)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 0.5E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux(machine, qubit_freq_sweep,qubit_if_sweep,
          qubit_index, n_avg = 4E3, cd_time = 20E3, final_plot = True, live_plot = True)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (5.753 GHz,  200.000 MHz)
# 2024-06-24 17:48:03,101 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,218 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,244 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,276 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,293 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,316 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 17:48:03,337 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Execution stopped by user!                                   ] 0.4% (n=18/4000.0) --> elapsed time: 3.68s
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.74s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.85s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (5.553 GHz,  200.000 MHz)
# 2024-06-24 18:15:52,003 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,127 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,165 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,199 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,217 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,242 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:15:52,266 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.56s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.82s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.953 GHz,  200.000 MHz)
# 2024-06-24 18:43:40,246 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,371 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,406 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,436 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,451 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,471 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 18:43:40,494 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.49s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.59s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.753 GHz,  200.000 MHz)
# 2024-06-24 19:11:28,646 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,764 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,796 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,824 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,839 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,861 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:11:28,885 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.56s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 827.87s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (4.153 GHz,  200.000 MHz)
# 2024-06-24 19:39:16,947 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,071 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,104 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,135 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,150 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,170 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:39:17,190 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 227.67s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (3.953 GHz,  200.000 MHz)
# 2024-06-24 19:43:15,665 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,793 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,853 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,887 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,903 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,927 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-24 19:43:15,949 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_qubit_spec_vs_fast_flux_3

# %%
# %matplotlib qt
data = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q2_qubit_spec_vs_fast_flux_3.nc")
data['I'].plot(x = list(data.coords.keys())[0], y = list(data.coords.keys())[1], cmap = "seismic")

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True, data_process_method = 'I')
machine.qubits[qubit_index].AC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %% [markdown]
# # TLS experiments

# %% [markdown]
# ## TLS SWAP spectroscopy

# %%
# Go back to the sweet spot and calibrate
machine.qubits[qubit_index].f_01 = int(np.floor(np.polyval(machine.qubits[qubit_index].AC_tuning_curve, 0.0) * 1E6)) + 0E6
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)

# %%
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q2 for (LO, IF) = (6.095 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r2 for (LO, IF) = (7.053 GHz, -49.578 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### coarse, no baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(16,100 + 0.1,1)
# ff_sweep_abs = np.arange(0.25,0.32,0.002)
ff_sweep_abs = np.arange(0.1,0.45,0.001)
machine, expt_dataset = Experiment.exp2D.SWAP.swap_coarse(machine, tau_sweep_abs, ff_sweep_abs, qubit_index, 
                      n_avg = 1E4, cd_time = 20E3, live_plot=True)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 3182.77s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q2_swap2D_4

# %% [markdown]
# ### fine, with baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(4,160,1)
# ff_sweep_abs = np.arange(0.1,0.45+1E-4,0.0005)
ff_sweep_abs = np.arange(0.29,0.33,0.0005)
machine, expt_dataset = Experiment.exp2D.SWAP.swap(machine, tau_sweep_abs, ff_sweep_abs, qubit_index,
                      n_avg = 4E3, cd_time = 20E3, live_plot=True)
# Out:
# Execution stopped by user!#############                      ] 57.9% (n=2315/4000.0) --> elapsed time: 1211.28s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q2_swap2D_317/4000.0) --> elapsed time: 1212.68s

# %%
# %matplotlib qt
expt_dataset['I'].plot(x = list(expt_dataset.coords.keys())[0], y = list(expt_dataset.coords.keys())[1], cmap = "seismic")

# %%
fft_dataset = Analysis.exp2D.SWAP_fft(expt_dataset, to_plot = True)

# %% [markdown]
# ### Add TLS iswap params

# %%
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0522\2024-05-22_q4_swap2D_4.nc")

# %% [markdown]
# SWAP plot, to find the SWAP param range for different TLS

# %%
# %matplotlib qt
expt_dataset['I'].plot(x = list(expt_dataset.coords.keys())[0], y = list(expt_dataset.coords.keys())[1], cmap = "seismic")
plt.show()

# %% [markdown]
# initialize the iswap params in quam

# %%
machine.flux_lines[qubit_index].iswap.length =[]
machine.flux_lines[qubit_index].iswap.level = []

# %% [markdown]
# #### TLS0

# %%
flux_min, flux_max = (0.276,0.284)
interaction_time_min, interaction_time_max = (4,18)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.28100 [V]
# iswap flux length:  10 [ns]
# Execution stopped by user!

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# #### TLS1

# %%
flux_min, flux_max = (0.32,0.335)
interaction_time_min, interaction_time_max = (10,28)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# #### TLS2

# %%
flux_min, flux_max = (0.375,0.385)
interaction_time_min, interaction_time_max = (18,30)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### estiguess of the TLS frequency, based on iswap flux level

# %%
freq_tls = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[qubit_index].iswap.level)
machine.qubits[qubit_index].f_tls = (np.floor(freq_tls*1E6)).tolist()    
machine = Analysis.set_machine(machine)

# %% [markdown]
# initialize pi_length_tls, pi_amp_tls

# %%
machine.qubits[qubit_index].pi_length_tls = [200] * len(machine.flux_lines[qubit_index].iswap.length)
machine.qubits[qubit_index].pi_amp_tls = [0.45] * len(machine.flux_lines[qubit_index].iswap.length)
machine = Analysis.set_machine(machine)
