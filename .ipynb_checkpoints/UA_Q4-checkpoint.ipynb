# %% [markdown]
# # Basic characterizations of UA Q4
# ### using Experiment and Analysis classes

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qm.octave import QmOctaveConfig
from quam import QuAM

from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
#from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber
import xarray as xr

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 0 # for UA Q4
TLS_index = 0 # for TLS of interest
dc_flux_index = 3 # for dc line
# Out:
# 2024-06-25 10:35:35,200 - qm - INFO     - Starting session: bf8fb996-8358-4a44-824a-6ed047fde299

# %%
Analysis = AnalysisHandle("quam_state_q3.json")
machine = Analysis.get_machine()
Experiment = ExperimentHandle(machine)

# %%
# Set voltage of flux line to 0 V
for i in np.arange(7):
    machine.dc_flux[i].dc_voltage = 0 + 0E6
machine = Analysis.set_machine(machine)

# %%
# initialize Labber-controlled hardware
# get values from QDAC first
#machine = Experiment.set_Labber.get_value_from_QDAC(machine)
# set all Labber settings
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
# set octave to external clock
#Experiment.set_octave.set_clock(machine)

# %%
# set to qubit
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)

# %%
machine.octaves[0].LO_sources[1].gain = 0
machine = Analysis.set_machine(machine)

# %%
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.954 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.930 GHz, -50.305 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # Qubit Readout

# %% [markdown]
# ## Time of Flight

# %%
# time_of_flight
# experiment
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.time_of_flight(machine,qubit_index, n_avg = 10E3, cd_time = 10E3, to_simulate = False, simulation_len = 1000)
# plot
# %matplotlib inline
dc_offset_i, dc_offset_q, delay = Analysis.exp1D.time_of_flight(expt_dataset)
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 42.61s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_time_of_flight_3
# DC offset to add to I: 0.000086 V
# DC offset to add to Q: 0.000859 V
# TOF to add: 0.0 ns

# %%
# update the offset
machine.global_parameters.downconversion_offset_I[0] += dc_offset_i
machine.global_parameters.downconversion_offset_Q[0] += dc_offset_q
machine.resonators[qubit_index].downconversion_offset_I = machine.global_parameters.downconversion_offset_I[0]
machine.resonators[qubit_index].downconversion_offset_Q = machine.global_parameters.downconversion_offset_Q[0]
#machine.global_parameters.time_of_flight = 304-0
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## Resonator spectroscopy

# %% [markdown]
# ### 1D resonator spectroscopy

# %%
# %matplotlib qt
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-5E6,5E6 + 1.0,0.05E6)
machine, expt_dataset = Experiment.exp1D.RR.rr_freq(machine, res_freq_sweep, qubit_index, n_avg = 1E3, cd_time = 10E3, live_plot = True,
                                                    readout_state = 'g', to_simulate = False, data_process_method = 'Amplitude')
# Readout in excited state
# machine, res_freq_sweep, sig_amp = Experiment.exp1D.RR.rr_freq(res_freq_sweep, qubit_index, res_index, flux_index, 
#                           n_avg = 1E3, cd_time = 5E3, readout_state = 'e', simulate_flag = False, simulation_len = 1000)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 2.35s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_res_spec_4

# %%
# find the minimal
# %matplotlib inline
res_freq = Analysis.exp1D.rr_freq(expt_dataset)
machine.resonators[qubit_index].f_readout = res_freq + 0E6
# Out:
# resonator frequency: 6880.050 MHz

# %%
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.938 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.930 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### 2D resonator spectroscopy

# %%
res_freq_sweep = machine.resonators[0].f_readout + np.arange(-6e6, 3e6, 0.1E6)
dc_flux_sweep = np.arange(-9,9.001,0.1)
# %matplotlib qt
machine, expt_dataset = Experiment.exp2D.RR.rr_vs_dc_flux(machine, res_freq_sweep, dc_flux_sweep, qubit_index,
                                                          n_avg = 1000, cd_time = 10E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=181/181) --> elapsed time: 348.03s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_res_spec2D

# %%
# %matplotlib inline
ham_param = Analysis.exp2D.rr_vs_dc_flux(expt_dataset, to_plot = True)
poly_param = Analysis.exp2D.qubit_vs_dc_flux_guess(ham_param = ham_param, to_plot = True)

# %%
# save the fitting parameters
machine.resonators[qubit_index].tuning_curve = ham_param
machine.qubits[qubit_index].DC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %%
# save the sweep spot flux according to fitted parameter
machine.dc_flux[dc_flux_index].max_frequency_point = Analysis.get_sweept_spot(poly_param)
machine = Analysis.set_machine(machine)

# %% [markdown]
# if 2D res spectroscopy is just to test the experiment, and I want to go back to sweet spot

# %%
machine = Analysis.update_machine_res_frequency_sweet_spot(machine, qubit_index, dc_flux_index) 
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50e6
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.954 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.930 GHz, -50.305 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # Qubit Sweet Spot Calibrations

# %% [markdown]
# ## 1D qubit spectroscopy @ sweep spot

# %%
if True: # for the DC flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].DC_tuning_curve,machine.dc_flux[dc_flux_index].max_frequency_point) * 1E6 # in Hz
else: # for the fast flux
    qubit_freq_est = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,0.0) * 1E6 # in Hz

qubit_freq_sweep = int(qubit_freq_est) + np.arange(-15E6, 15E6 + 1, 0.5E6)
    
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.Rabi.qubit_freq(machine, qubit_freq_sweep, qubit_index, pi_amp_rel = 1.0, live_plot = True,
                                                         ff_amp = 0.0, n_avg = 1E4, cd_time = 30E3, to_simulate = False, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 19.33s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_spec_5
# Execution stopped by user!

# %%
# %matplotlib inline
qubit_freq = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'I')
machine.qubits[qubit_index].f_01 = qubit_freq + 0E6
# Out:
# peak frequency:  5902.6 [MHz]

# %%
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.953 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.930 GHz, -50.305 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ## Rabi

# %% [markdown]
# ### Time Rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 240 + 0.1, 4)  # in ns
machine, expt_dataset = Experiment.exp1D.Rabi.rabi_length(machine, rabi_duration_sweep, qubit_index, pi_amp_rel = 1.0, live_plot = True, 
                                                          n_avg = 5E3, cd_time = 25E3, to_simulate = False, data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 7.67s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_time_rabi

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", to_plot = True, data_process_method = 'I')
# Out:
# rabi_pi_pulse: 101.1 [ns]
# pi period: 99.72 [ns]

# %%
machine.qubits[qubit_index].pi_length = 100
# machine.qubits[qubit_index].pi_amp[0] = 0.0270983
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.1, 2.0, 0.025) 
machine, expt_dataset = Experiment.exp1D.Rabi.rabi_amp(machine, rabi_amp_sweep_rel, qubit_index, ff_amp = 0.0, live_plot = True,
                                       n_avg = 10E3, cd_time = 20E3, data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 16.71s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_power_rabi

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", data_process_method = 'Amplitude')
machine.qubits[qubit_index].pi_amp = pi_pulse_amp
machine = Analysis.set_machine(machine)
# Out:
# rabi_pi_amp: 0.019 [V]
# pi period: 0.018 [V]

# %% [markdown]
# ## Single-Shot Readout

# %% [markdown]
# ### Find frequency between g, e

# %%
# %matplotlib qt
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-5E6,5E6 + 1.0,0.05E6)
machine, expt_dataset = Experiment.exp1D.RR.rr_freq_ge(machine, res_freq_sweep, qubit_index, n_avg = 1E4, cd_time = 10E3,
                                                    to_simulate = False, simulation_len = 1000, live_plot = True, data_process_method = 'Phase')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 44.99s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_res_spec_ge

# %%
# %matplotlib inline
res_freq_phase = Analysis.exp1D.rr_freq_ge(expt_dataset)
# Out:
# resonator frequency: 6879.495 MHz

# %%
# doesn't have to update. Use res_freq_phase
machine.resonators[qubit_index].f_readout = res_freq_phase + 0E6
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Experiment.set_octave.calibration(machine, qubit_index)
machine = Analysis.set_machine(machine)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.953 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.929 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### IQ blobs

# %%
# %matplotlib inline
machine, expt_dataset = Experiment.exp1D.RR.single_shot_IQ_blob(machine, qubit_index, n_avg = 30E3, cd_time = 25E3, final_plot = False)
# Out:
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_single_shot_IQ_16-> elapsed time: 1.61s

# %%
# %matplotlib inline
angle, threshold, fidelity, gg, ge, eg, ee = Analysis.exp1D.two_state_discriminator(expt_dataset)
# Out:
# 			Fidelity Matrix:
# 			-----------------
# 			| 0.885 | 0.115 |
# 			----------------
# 			| 0.287 | 0.713 |
# 			-----------------
# 			IQ plane rotated by: 1.3°
# 			Threshold: 1.246e-03
# 			Fidelity: 79.9%

# %%
# set the rotation angle
machine.resonators[qubit_index].rotation_angle -= angle # note this is the change value not the absolute value!
machine.resonators[qubit_index].ge_threshold = threshold
machine = Analysis.set_machine(machine)

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.39
machine.resonators[qubit_index].readout_pulse_length = 1100
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout freq optimization

# %%
res_freq_sweep = machine.resonators[qubit_index].f_readout + np.arange(-1.5E6, 1.5E6 + 1, 0.05E6)

# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_freq_optimization(machine, res_freq_sweep, qubit_index, n_avg = 5E4, cd_time = 25E3, 
                                                           final_plot = True, live_plot = True)
# Out:
# Execution stopped by user!                                   ] 31.7% (n=15858/50000.0) --> elapsed time: 51.21s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q3_single_shot_freq_30) --> elapsed time: 51.88s
# The optimal readout frequency is 6879288983.0 Hz (SNR=2.2268161302647598)

# %%
# %matplotlib inline
res_freq = Analysis.exp1D.peak_fit(expt_dataset,method="Gaussian", data_process_method = 'SNR')
# Out:
# peak frequency:  6879.3 [MHz]
# Execution stopped by user!

# %%
machine.resonators[qubit_index].f_readout = res_freq + 0E6
machine.octaves[0].LO_sources[0].LO_frequency = machine.resonators[qubit_index].f_readout + 50E6
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.938 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.929 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### Readout pulse amp and duration (by qubit relaxation during readout)

# %%
# %matplotlib qt
res_duration_sweep_abs = np.arange(300, 2000 + 1, 60)
res_amp_sweep_abs = np.arange(0.15,0.45,0.002)
machine, expt_dataset = Experiment.exp2D.RR.rr_pulse_optimize(machine, res_duration_sweep_abs, res_amp_sweep_abs, qubit_index, n_avg=1E3, 
                                                              cd_time=25E3, live_plot = True, data_process_method = 'I')
# Out:
# Execution stopped by user!                                   ] 21.0% (n=210/1000.0) --> elapsed time: 26.02s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q3_res_pulse_optimize--> elapsed time: 27.09s

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.45
machine.resonators[qubit_index].readout_pulse_length = 600
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout duration optimization

# %%
division_length = 40
# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_duration_optimization(machine, division_length, qubit_index,
                                                                    readout_len = 2000, n_avg = 2E4, cd_time = 25E3)
# Out:
# Integration weights chunk-size length in ns: 40
# The readout has been sliced in the following number of divisions 50
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.74s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.75s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.77s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.78s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.80s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.81s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.83s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.84s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.86s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.87s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.89s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.90s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.91s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.93s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.95s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.96s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.98s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 1.99s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.01s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.02s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.32s
# Progress: [##################################################] 100.0% (n=20000/20000.0) --> elapsed time: 2.33s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q3_single_shot_len_3
# The optimal readout duration is 1320 ns (Fidelity=73.0%)

# %%
machine.resonators[qubit_index].readout_pulse_length = 1320
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### Readout amp optimization

# %%
res_amp_sweep = np.arange(0.5,1.5 + 1E-4, 0.01)

# %matplotlib qt
machine, expt_dataset = Experiment.exp1D.RR.single_shot_amp_optimization(machine, res_amp_sweep, qubit_index,
                              n_avg = 5E3, cd_time = 25E3, final_plot= True)

# %%
# %matplotlib inline
readout_amp = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'Fidelity')

# %%
machine.resonators[qubit_index].readout_pulse_amp = 0.48
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## Qubit T1

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(100,30E3+1,1E3)
machine, expt_dataset = Experiment.exp1D.T1.qubit_T1(machine, tau_sweep_abs, qubit_index, n_avg = 4E3, cd_time = 40E3, live_plot = True,
                                                               to_simulate = False, simulation_len = 15_000, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7.09s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_T1

# %%
# %matplotlib inline
qubit_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
machine.qubits[qubit_index].T1 = qubit_T1 + 0E6
machine = Analysis.set_machine(machine)
# Out:
# Qubit T1: 4.9 [us]

# %% [markdown]
# ## Qubit Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(16, 12000 + 0.1, 60)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Ramsey.ramsey(machine, ramsey_duration_sweep, qubit_index, detuning = 1E6, live_plot = True,
                                                       n_avg = 2E3, cd_time = 25E3, to_simulate = False, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 12.94s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_ramsey

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [6, 3]
q_T2star = Analysis.exp1D.ramsey(expt_dataset, data_process_method = 'I')
machine.qubits[qubit_index].T2 = q_T2star + 0E6
machine = Analysis.set_machine(machine)
# Out:
# Qubit T2*:  1609.7 [ns]
# Exponent n =  1.8
# Detuning =  1.0 [MHz]

# %% [markdown]
# ## ef transition

# %% [markdown]
# ### ef frequency

# %%
# %matplotlib qt
ef_freq_sweep = machine.qubits[qubit_index].f_01 + np.arange(-190E6, -150E6 + 1, 0.5E6) 
machine, expt_dataset = Experiment.exp1D.Rabi.ef_freq(machine, ef_freq_sweep, qubit_index, pi_amp_rel_ef = 1.0, n_avg = 2E3, live_plot = True,
                                                      cd_time = 30E3, readout_state = 'g', to_simulate = False, data_process_method = 'I')

# %%
# %matplotlib inline
ef_freq = Analysis.exp1D.peak_fit(expt_dataset, method="Gaussian", data_process_method = 'I')

# %%
machine.qubits[qubit_index].anharmonicity = machine.qubits[qubit_index].f_01 - ef_freq
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition time Rabi

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 240 + 0.1, 4)  # in ns
rabi_duration_sweep = rabi_duration_sweep.astype(int)
machine, expt_dataset = Experiment.exp1D.Rabi.ef_rabi_length(machine, rabi_duration_sweep, qubit_index, pi_amp_rel_ef = 1.0, live_plot = True,
                                                                             n_avg = 2E3, cd_time = 30E3, readout_state = 'g', 
                                                                             to_simulate = False, simulation_len = 10_000, data_process_method = 'I')

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, data_process_method = 'I')

# %%
machine.qubits[qubit_index].pi_length_ef = 180
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### ef transition power Rabi

# %%
# %matplotlib qt
rabi_amp_sweep_rel = np.arange(0.2, 2.0, 0.025) 
machine, expt_dataset = Experiment.exp1D.Rabi.ef_rabi_amp(machine, rabi_amp_sweep_rel, qubit_index, n_avg = 2E3, cd_time = 30E3, live_plot = True,
                                                          readout_state = 'g', to_simulate = False, simulation_len = 1000, data_process_method = 'I')

# %%
# %matplotlib inline
pi_pulse_amp = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", data_process_method = 'I')

# %%
machine.qubits[qubit_index].pi_amp_ef = pi_pulse_amp
machine = Analysis.set_machine(machine)

# %% [markdown]
# # Qubit Tuning Curves

# %% [markdown]
# ## 2D qubit spectroscopy vs dc flux

# %%
# try the experiment
# %matplotlib qt
dc_flux_sweep = machine.dc_flux[dc_flux_index].max_frequency_point + np.arange(-1,1+1E-4,0.05)
qubit_if_sweep = np.arange(-30E6, 30E6, 1E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_dc_flux(machine, dc_flux_sweep, qubit_if_sweep, qubit_index,
                                 n_avg = 500, cd_time = 25E3, final_plot = True, live_plot = False ,  data_process_method = 'Amplitude')
# Out:
# Progress: [##################################################] 100.0% (n=41/41) --> elapsed time: 342.88s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_res_spec_vs_dc_flux_2
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_qubit_spec_vs_dc_flux_2

# %%
expt_data = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0517\2024-05-17_q1_qubit_spec_vs_dc_flux_9.nc")

# %%
# udpate the sweet spot
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 2, to_plot = False ,  data_process_method = 'Amplitude')
machine.dc_flux[dc_flux_index].max_frequency_point = Analysis.get_sweept_spot(poly_param) + 0E1
print(f"sweet spot flux: {machine.dc_flux[dc_flux_index].max_frequency_point:.5f} V")
# Out:
# sweet spot flux: -1.25581 V

# %%
# save the sweep spot flux according to fitted parameter
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True,  data_process_method = 'Amplitude')
machine.qubits[qubit_index].DC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %%
# go to the sweet spot, if needed
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## 2D qubit spectroscopy vs fast flux

# %%
# set DC voltage to sweet spot, after possible dc flux sweep
machine.dc_flux[dc_flux_index].dc_voltage = machine.dc_flux[dc_flux_index].max_frequency_point
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### slow version, compiling 1D scans

# %%
# try the experiment
# %matplotlib qt
#ff_sweep = np.arange(-0.02,-0.28-1E-4,-0.02)
ff_sweep = np.arange(0,0.25+1E-4,0.05)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 1E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux_slow(machine, ff_sweep,qubit_if_sweep,
      qubit_index, ff_to_dc_ratio = None, n_avg = 1E3, cd_time = 25E3)
# Out:
# ------------------------------------- Octave calibration starts...7% (n=4/6) --> elapsed time: 20.87s
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.369 GHz,  290.000 MHz)
# 2024-06-10 09:45:54,207 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,333 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,366 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,397 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,413 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,436 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-10 09:45:54,459 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=6/6) --> elapsed time: 39.78s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_qubit_spec_vs_fast_flux

# %%
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_qubit_spec_vs_fast_flux.nc")

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True, data_process_method = 'Amplitude', fit_type = 'dip')
machine.qubits[qubit_index].AC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### fast version, runs blockwise 2D sweeps

# %%
# %matplotlib qt
q_freq_max = np.floor(np.polyval(machine.qubits[qubit_index].AC_tuning_curve, 0.0) * 1E6)
qubit_freq_sweep = np.arange(q_freq_max, 4.4E9, -5E6)
qubit_if_sweep = np.arange(-60E6, 60E6 + 1, 0.5E6)
machine, expt_dataset = Experiment.exp2D.Rabi.qubit_freq_vs_fast_flux(machine, qubit_freq_sweep,qubit_if_sweep,
          qubit_index, n_avg = 0.4E4, cd_time = 20E3, final_plot = True, live_plot = True)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.604 GHz,  200.000 MHz)
# 2024-06-25 11:39:54,173 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,291 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,335 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,368 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,385 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,408 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 11:39:54,430 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.41s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.60s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.404 GHz,  200.000 MHz)
# 2024-06-25 12:07:44,370 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,490 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,521 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,550 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,564 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,584 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:07:44,604 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.54s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.15s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (4.804 GHz,  200.000 MHz)
# 2024-06-25 12:35:34,403 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,534 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,571 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,604 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,620 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,644 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 12:35:34,668 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.32s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.19s
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (4.604 GHz,  200.000 MHz)
# 2024-06-25 13:03:23,450 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,573 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,610 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,646 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,664 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,687 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# 2024-06-25 13:03:23,710 - qm - ERROR    - Runtime errors were detected. Please fetch the execution report using job.execution_report() for more information
# ------------------------------------- Octave calibration finished.
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 828.53s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 435.00s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_qubit_spec_vs_fast_flux
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!
# Execution stopped by user!

# %%
# %matplotlib qt
expt_data = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_qubit_spec_vs_fast_flux.nc")
expt_data['I'].plot(x = "Fast_Flux", y = "Qubit_Frequency", cmap="seismic")

# %%
# save the fitted tuning curve
# %matplotlib inline
poly_param = Analysis.exp2D.qubit_vs_flux(expt_dataset, fit_order = 4, to_plot = True, data_process_method = 'I', fit_type = 'peak')
machine.qubits[qubit_index].AC_tuning_curve = poly_param
machine = Analysis.set_machine(machine)

# %% [markdown]
# # TLS experiments

# %% [markdown]
# ## TLS SWAP spectroscopy

# %%
# Go back to the sweet spot and calibrate
machine.qubits[qubit_index].f_01 = int(np.floor(np.polyval(machine.qubits[qubit_index].AC_tuning_curve, 0.0) * 1E6)) + 0E6
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)

# %%
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.954 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.929 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# ### coarse, no baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(16,100 + 0.1,4)
ff_sweep_abs = np.arange(0.1,0.45,0.002)
machine, expt_dataset = Experiment.exp2D.SWAP.swap_coarse(machine, tau_sweep_abs, ff_sweep_abs, qubit_index, 
                      n_avg = 1E3, cd_time = 25E3, live_plot=True)
# Out:
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 196.98s
# Progress: [##################################################] 100.0% (n=1000/1000.0) --> elapsed time: 197.55s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_swap2D

# %%
data = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0610\2024-06-10_q3_swap2D.nc")
data['Amplitude'].plot(x = "Fast_Flux", y = "Interaction_Time", cmap="seismic")

# %% [markdown]
# ### fine, with baking

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(4,160,2)
ff_sweep_abs = np.arange(0.1,0.45+1E-4,0.002)
machine, expt_dataset = Experiment.exp2D.SWAP.swap(machine, tau_sweep_abs, ff_sweep_abs, qubit_index,
                      n_avg = 1E4, cd_time = 25E3, live_plot=True)
# Out:
# Execution stopped by user!                                   ] 26.7% (n=2671/10000.0) --> elapsed time: 1906.62s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_swap2D_272/10000.0) --> elapsed time: 1907.78s

# %%
# %matplotlib qt
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0625\2024-06-25_q3_swap2D_2.nc")
expt_dataset['I'].plot(x = list(expt_dataset.coords.keys())[0], y = list(expt_dataset.coords.keys())[1], cmap = "seismic")

# %%
fft_dataset = Analysis.exp2D.SWAP_fft(expt_dataset, to_plot = True)

# %% [markdown]
# ### Add TLS iswap params

# %%
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0519\2024-05-19_q1_swap2D_2.nc")

# %% [markdown]
# SWAP plot, to find the SWAP param range for different TLS

# %%
# %matplotlib qt
expt_dataset['Amplitude'].plot(x = list(expt_dataset.coords.keys())[0], y = list(expt_dataset.coords.keys())[1], cmap = "seismic")
plt.show()

# %% [markdown]
# initialize the iswap params in quam

# %%
machine.flux_lines[qubit_index].iswap.length =[]
machine.flux_lines[qubit_index].iswap.level = []

# %% [markdown]
# #### TLS0

# %%
flux_min, flux_max = (0.18,0.21)
interaction_time_min, interaction_time_max = (10,50)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.19200 [V]
# iswap flux length:  32 [ns]

# %%
machine.flux_lines[qubit_index].iswap.level
# Out:
# [0.192, 0.274, 0.374]

# %%
machine.flux_lines[qubit_index].iswap.length
# Out:
# [32, 18, 20]

# %%
machine.flux_lines[qubit_index].iswap.length[0] = iswap_time
machine.flux_lines[qubit_index].iswap.level[0] = iswap_flux
machine = Analysis.set_machine(machine)

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# #### TLS1

# %%
flux_min, flux_max = (0.264,0.282)
interaction_time_min, interaction_time_max = (12,24)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.27400 [V]
# iswap flux length:  18 [ns]

# %%
machine.flux_lines[qubit_index].iswap.length[1] = iswap_time
machine.flux_lines[qubit_index].iswap.level[1] = iswap_flux
machine = Analysis.set_machine(machine)

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# #### TLS2

# %%
flux_min, flux_max = (0.278,0.286)
interaction_time_min, interaction_time_max = (22,34)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.28200 [V]
# iswap flux length:  28 [ns]

# %%
machine.flux_lines[qubit_index].iswap.length[2] = iswap_time
machine.flux_lines[qubit_index].iswap.level[2] = iswap_flux
machine = Analysis.set_machine(machine)

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### TLS3

# %%
flux_min, flux_max = (0.35,0.3675)
interaction_time_min, interaction_time_max = (10,30)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.35800 [V]
# iswap flux length:  24 [ns]

# %%
machine.flux_lines[qubit_index].iswap.length.append(iswap_time)
machine.flux_lines[qubit_index].iswap.level.append(iswap_flux)
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### TLS4

# %%
flux_min, flux_max = (0.37,0.39)
interaction_time_min, interaction_time_max = (0,24)
flux_range = (flux_min, flux_max)
interaction_time_range = (interaction_time_min, interaction_time_max)

# %%
# %matplotlib inline
iswap_flux, iswap_time = Analysis.exp2D.SWAP_find_iswap(expt_dataset, flux_range, interaction_time_range, to_plot = True)
# Out:
# iswap flux level:  0.37400 [V]
# iswap flux length:  16 [ns]

# %%
machine.flux_lines[qubit_index].iswap.length[4]=iswap_time
machine.flux_lines[qubit_index].iswap.level[4]=iswap_flux
machine = Analysis.set_machine(machine)

# %% [markdown]
# ### estiguess of the TLS frequency, based on iswap flux level

# %%
freq_tls = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[qubit_index].iswap.level)
machine.qubits[qubit_index].f_tls = (np.floor(freq_tls*1E6)).tolist()    
machine = Analysis.set_machine(machine)

# %% [markdown]
# initialize pi_length_tls, pi_amp_tls

# %%
machine.qubits[qubit_index].pi_length_tls = [200] * len(machine.flux_lines[qubit_index].iswap.length)
machine.qubits[qubit_index].pi_amp_tls = [0.45] * len(machine.flux_lines[qubit_index].iswap.length)
machine = Analysis.set_machine(machine)

# %%
freq_tls = np.polyval(machine.qubits[qubit_index].AC_tuning_curve,machine.flux_lines[qubit_index].iswap.level)

# %%
freq_tls
# Out:
# array([5663.93305623, 5411.2451049 , 5381.32639457, 5047.18168238,
#        4964.81890685])
