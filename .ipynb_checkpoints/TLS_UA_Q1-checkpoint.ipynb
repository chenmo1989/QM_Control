# %% [markdown]
# # TLS Experiments of LA Q1

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qm.octave import QmOctaveConfig
from quam import QuAM

from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
#from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber
import xarray as xr

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 0 # for UA Q2
TLS_index = 1 # for TLS of interest
dc_flux_index = 1 # for dc line
# Out:
# 2024-06-24 09:04:50,248 - qm - INFO     - Starting session: 42248c4e-ea56-40f7-8b02-456a6e9a6959

# %%
Analysis = AnalysisHandle("quam_state_q1.json")
machine = Analysis.get_machine()
Experiment = ExperimentHandle(machine)

# %%
# initialize Labber-controlled hardware
# get values from QDAC first
#machine = Experiment.set_Labber.get_value_from_QDAC(machine)
# set all Labber settings
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
# set octave to external clock
Experiment.set_octave.set_clock(machine)
# Out:
# ------------Octave set to External_10MHz

# %%
# set for the qubit
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q1 for (LO, IF) = (6.249 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r1 for (LO, IF) = (7.184 GHz, -50.000 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # TLS Characterizations

# %%
TLS_index = 1

# %% [markdown]
# ## TLS T1 (swap)

# %%
# %matplotlib qt
# tau_sweep_abs = np.arange(20,2000E3+1,5E4)
tau_sweep_abs = np.arange(20,3000E3+1,5E4)
machine, expt_dataset = Experiment.exp1D.T1.TLS_T1(machine, tau_sweep_abs, qubit_index, TLS_index,
                   n_avg = 1E4, cd_time_qubit = 20E3, cd_time_TLS = 3000E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 2709.69s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_T1_swap_2

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T1: 283.8 [us]

# %% [markdown]
# # TLS Driving Pulses

# %% [markdown]
# ## set rf_gain for TLS pulse

# %%
machine.octaves[0].LO_sources[1].gain = 10
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS spectroscopy

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_tls[TLS_index] + np.arange(-30E6,30E6+1,1E6)
machine, expt_dataset = Experiment.exp1D.Rabi.TLS_freq(machine, TLS_freq_sweep, qubit_index, TLS_index,
                  n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True, data_process_method = 'I')
# Out:
# Execution stopped by user!                                   ] 3.2% (n=159/5000.0) --> elapsed time: 14.58s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_spec_50.0) --> elapsed time: 15.24s

# %%
# %matplotlib inline
TLS_freq = Analysis.exp1D.peak_fit(expt_dataset, method = "Gaussian", data_process_method = 'I')
# TLS_freq = 5421.00E6
machine.qubits[qubit_index].f_tls[TLS_index] = TLS_freq + 0E6
# machine.qubits[qubit_index].f_tls[TLS_index] = 5439.35E6 + 0E6 
machine = Analysis.set_machine(machine)
# Out:
# peak frequency:  5426.3 [MHz]

# %% [markdown]
# ## TLS rabi

# %% [markdown]
# change rf gain of octave

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 150 + 0.1, 1)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Rabi.TLS_rabi_length(machine, rabi_duration_sweep, qubit_index, TLS_index,
                      n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 206.72s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_time_rabi_5

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, method = "Decay", to_plot = True, data_process_method = 'I')
# Out:
# rabi_pi_pulse: 10.3 [ns]
# pi period: 68.50 [ns]
# T2rabi: 262.5 [ns]

# %%
0.45 * 76 / 78.8
# Out:
# 0.434010152284264

# %%
machine.qubits[qubit_index].pi_amp_tls[TLS_index]
# Out:
# 0.4102827763496144

# %%
machine.qubits[qubit_index].pi_amp_tls[TLS_index] = 0.434010152284264
machine.qubits[qubit_index].pi_length_tls[TLS_index] = 76
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(16, 1500 + 0.1, 16)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Ramsey.TLS_ramsey(machine, ramsey_duration_sweep, qubit_index, TLS_index,
                       n_avg = 5E3, detuning = 2E6, cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True, data_process_method = 'I')
# Out:
# Execution stopped by user!############                       ] 55.3% (n=2763/5000.0) --> elapsed time: 390.84s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_ramsey_50.0) --> elapsed time: 391.04s

# %%
# %matplotlib inline
tls_T2star = Analysis.exp1D.ramsey(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T2*:  36.8 [ns]
# Exponent n =  0.7
# Detuning =  2.8 [MHz]

# %% [markdown]
# As a sanity check, run fft, see if there are multiple peaks

# %%
fft_dataset = Analysis.exp1D.fft(expt_dataset, data_process_method = 'I')

# %% [markdown]
# ## TLS T1 with direct driving

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(20,3000E3+1,5E4)
machine, expt_dataset = Experiment.exp1D.T1.TLS_T1_drive(machine, tau_sweep_abs, qubit_index, TLS_index,
                     n_avg = 1E4, cd_time_qubit = 20E3, cd_time_TLS = 3000E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 2697.39s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 2697.96s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_T1_drive

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T1: 423.7 [us]

# %% [markdown]
# # TLS Dynamical Decoupling

# %%
# %matplotlib inline
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0612\2024-06-12_q1t0_tls_cpmg8.nc")
# expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
# plt.title(expt_dataset.attrs['long_name'])
N_CPMG = 8
TLS_T2dd = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau = 2 * N_CPMG)
# Out:
# Qubit T2*:  165.6 [us]
# Exponent n =  2.8

# %% [markdown]
# ## Longer Timescale Decay

# %% [markdown]
# ### echo

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(500, 200E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_echo(machine, tau_sweep_abs, qubit_index, TLS_index, n_avg = 5E3,
                     cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 860.14s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0624\2024-06-24_q1t1_tls_echo
# Execution stopped by user!

# %%
# %matplotlib inline
TLS_T2echo = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau =2)
# Out:
# Qubit T2*:  21.0 [us]
# Exponent n =  0.8
# Execution stopped by user!

# %% [markdown]
# ### CPMG-2

# %%
# %matplotlib qt
N_CPMG = 2
tau_sweep_abs = np.arange(500, 200E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 959.97s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 960.01s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0612\2024-06-12_q1t0_tls_cpmg2

# %%
# %matplotlib inline
TLS_T2dd = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau = 2 * N_CPMG)
# Out:
# Qubit T2*:  28.5 [us]
# Exponent n =  1.0
# Execution stopped by user!

# %% [markdown]
# ### CPMG-8

# %%
# %matplotlib qt
N_CPMG = 8
tau_sweep_abs = np.arange(500, 200E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 1500E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 1556.75s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 1556.79s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0612\2024-06-12_q1t0_tls_cpmg8

# %%
# %matplotlib inline
TLS_T2dd = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau = 2 * N_CPMG)
# Out:
# Qubit T2*:  165.6 [us]
# Exponent n =  2.8
# Execution stopped by user!

# %% [markdown]
# ## Shorter Timescale Dynamics

# %%
## Set values beforehand so we do not need to change it every time leading to potential mess ups

tau_sweep_abs = np.arange(20, 20E3 + 0.1, 4)  # in units of ns
n_avg = 5E3
cd_time_qubit = 20E3
cd_time_TLS = 200E3

# %%
N_CPMG_sweep = np.arange(2, 32 + 0.1, 2)
tau_sweep_abs = tau_sweep_abs
for N in N_CPMG_sweep:
    N = int(N)
    machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 6534.77s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 6534.81s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0614\2024-06-14_q1t0_tls_cpmg2_6
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 7539.87s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 7539.91s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0614\2024-06-14_q1t0_tls_cpmg4_2
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 8542.41s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 8542.45s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0614\2024-06-14_q1t0_tls_cpmg6
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 9546.14s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 9546.19s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0614\2024-06-14_q1t0_tls_cpmg8_5
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 10550.03s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 10550.08s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg10
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 11553.76s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 11553.80s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg12
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 12557.53s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 12557.57s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg14
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 13561.23s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 13561.27s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg16
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 14565.12s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 14565.17s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg18
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 15568.83s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 15568.88s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg20
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 16572.78s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 16572.81s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0615\2024-06-15_q1t0_tls_cpmg22
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 17576.44s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 17576.49s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0616\2024-06-16_q1t0_tls_cpmg24
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 18580.28s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 18580.32s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0616\2024-06-16_q1t0_tls_cpmg26
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 19584.06s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 19584.10s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0616\2024-06-16_q1t0_tls_cpmg28
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 20587.81s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 20587.86s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0616\2024-06-16_q1t0_tls_cpmg30
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 21591.57s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 21591.61s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0617\2024-06-17_q1t0_tls_cpmg32

# %% [markdown]
# ### CPMG-2

# %%
# %matplotlib inline
N_CPMG = 2
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7856.31s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7856.37s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7856.41s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7856.45s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 7856.49s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg2

# %% [markdown]
# ### CPMG-4

# %%
# %matplotlib inline
N_CPMG = 4
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8107.09s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8107.14s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8107.18s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8107.22s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg4

# %%
# %matplotlib inline
# expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0520\2024-05-20_q1t1_tls_cpmg4.nc")
# expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
# plt.title(expt_dataset.attrs['long_name'])

# %% [markdown]
# ### CPMG-6

# %%
# %matplotlib inline
N_CPMG = 6
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8358.09s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8358.13s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8358.17s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8358.20s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg6

# %% [markdown]
# ### CPMG-8

# %%
# %matplotlib inline
N_CPMG = 8
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 95.19s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 95.24s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0614\2024-06-14_q1t0_tls_cpmg8_4

# %%
# %matplotlib inline
# expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0607\2024-06-07_q1t0_tls_cpmg8_3.nc")
# expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
# plt.title(expt_dataset.attrs['long_name'])

# %% [markdown]
# ### CPMG-10

# %%
# %matplotlib inline
N_CPMG = 10
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8859.72s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8859.78s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 8859.82s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg10

# %% [markdown]
# ### CPMG-12

# %%
# %matplotlib inline
N_CPMG = 12
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9110.77s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9110.81s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9110.85s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg12

# %% [markdown]
# ### CPMG-14

# %%
# %matplotlib inline
N_CPMG = 14
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-16

# %%
# %matplotlib inline
N_CPMG = 16
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9612.59s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9612.64s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 9612.68s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0613\2024-06-13_q1t0_tls_cpmg16

# %%
# %matplotlib inline
# expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0520\2024-05-20_q1t1_tls_cpmg16.nc")
# expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
# plt.title(expt_dataset.attrs['long_name'])
# Out:
# Text(0.5, 1.0, 'TLS CPMG-16')

# %% [markdown]
# ### CPMG-18

# %%
# %matplotlib inline
N_CPMG = 18
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-20

# %%
# %matplotlib inline
N_CPMG = 20
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-22

# %%
# %matplotlib inline
N_CPMG = 22
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-24

# %%
# %matplotlib inline
N_CPMG = 24
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-26

# %%
# %matplotlib inline
N_CPMG = 26
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-28

# %%
# %matplotlib inline
N_CPMG = 28
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-30

# %%
# %matplotlib inline
N_CPMG = 30
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-32

# %%
# %matplotlib inline
N_CPMG = 32
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)

# %% [markdown]
# ### CPMG-40

# %%
# %matplotlib qt
N_CPMG = 40
tau_sweep_abs = tau_sweep_abs
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = n_avg, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd_time_TLS, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 937.50s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 937.53s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q1t1_tls_cpmg40
# Execution stopped by user!

# %% [markdown]
# ### Rabi CPMG

# %%
cd_time_TLS = np.arange(100E3, 2000E3 + 0.1, 100E3)
cd_time_TLS = cd_time_TLS.astype(int)
type(cd_time_TLS[0])
# Out:
# numpy.int32

# %%
cd_time_TLS = np.arange(100E3, 2000E3 + 0.1, 100E3)
cd_time_TLS = cd_time_TLS.astype(float)
a = cd_time_TLS[0].item()
type(a)
# Out:
# float

# %%
# %matplotlib qt

cd_time_qubit = 20E3
# cd_time_TLS = 200E3

N_CPMG_sweep = np.arange(2, 32 + 0.1, 2) 

# tau = [156, 568] # in units of ns
tau = np.arange(540, 592  + 0.1, 4)
cd_time_TLS = np.arange(100E3, 2000E3 + 0.1, 100E3)
cd_time_TLS = cd_time_TLS.astype(float)

for t in tau:
    for cd in cd_time_TLS:
        cd = cd.item()
        machine, expt_dataset = Experiment.exp1D.Rabi.TLS_CPMG_Rabi(machine, N_CPMG_sweep, t, qubit_index, TLS_index, 
                         n_avg = 10E3, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd)
# Out:
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722460.60s
# Elapsed duration 50.226083 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722525.06s
# Elapsed duration 64.259471 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722607.95s
# Elapsed duration 82.663223 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722705.86s
# Elapsed duration 97.724957 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722818.12s
# Elapsed duration 112.036935 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718722947.81s
# Elapsed duration 129.496518 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718723091.34s
# Elapsed duration 143.338316 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718723253.99s
# Elapsed duration 162.413988 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718723432.27s
# Elapsed duration 178.076304 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718723626.64s
# Elapsed duration 194.177279 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718723836.35s
# Elapsed duration 209.508033 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718724059.14s
# Elapsed duration 222.592863 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718724301.62s
# Elapsed duration 242.275618 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718724558.18s
# Elapsed duration 256.341086 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718724832.22s
# Elapsed duration 273.8372 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718725121.01s
# Elapsed duration 288.593611 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718725425.43s
# Elapsed duration 304.221369 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718725747.47s
# Elapsed duration 321.098998 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726083.39s
# Elapsed duration 335.643527 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726438.42s
# Elapsed duration 354.827805 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi540.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726488.95s
# Elapsed duration 50.330046 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726553.96s
# Elapsed duration 64.811152 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726637.26s
# Elapsed duration 83.120452 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726734.78s
# Elapsed duration 97.325513 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726846.34s
# Elapsed duration 111.36577 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718726977.08s
# Elapsed duration 130.556518 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718727120.91s
# Elapsed duration 143.639139 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718727284.26s
# Elapsed duration 163.117246 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718727460.72s
# Elapsed duration 176.22561 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718727655.36s
# Elapsed duration 194.418304 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718727865.68s
# Elapsed duration 210.088505 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718728089.66s
# Elapsed duration 223.760858 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718728333.38s
# Elapsed duration 243.478911 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718728589.34s
# Elapsed duration 255.719435 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718728865.53s
# Elapsed duration 275.974771 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718729154.31s
# Elapsed duration 288.566648 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718729459.08s
# Elapsed duration 304.54117 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718729781.11s
# Elapsed duration 321.805921 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730117.16s
# Elapsed duration 335.816962 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730474.24s
# Elapsed duration 356.831007 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi544.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730524.59s
# Elapsed duration 50.112638 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730589.32s
# Elapsed duration 64.507705 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730672.15s
# Elapsed duration 82.614871 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730771.18s
# Elapsed duration 98.807951 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718730882.77s
# Elapsed duration 111.394941 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731012.40s
# Elapsed duration 129.415932 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731156.31s
# Elapsed duration 143.696344 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731319.82s
# Elapsed duration 163.24312 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731497.65s
# Elapsed duration 177.605409 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731690.83s
# Elapsed duration 192.94932 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718731900.79s
# Elapsed duration 209.725541 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718732125.55s
# Elapsed duration 224.513783 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718732367.98s
# Elapsed duration 242.194657 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718732624.39s
# Elapsed duration 256.212845 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718732900.19s
# Elapsed duration 275.552792 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718733189.69s
# Elapsed duration 289.271464 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718733493.54s
# Elapsed duration 303.603989 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718733816.56s
# Elapsed duration 322.793082 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734152.73s
# Elapsed duration 335.961038 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734508.66s
# Elapsed duration 355.736587 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi548.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734558.83s
# Elapsed duration 49.925543 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734624.19s
# Elapsed duration 65.141388 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734705.74s
# Elapsed duration 81.31372 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734803.79s
# Elapsed duration 97.832972 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718734916.50s
# Elapsed duration 112.498851 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735048.62s
# Elapsed duration 131.891943 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735193.31s
# Elapsed duration 144.47755 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735358.46s
# Elapsed duration 164.186818 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735535.79s
# Elapsed duration 177.111263 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735729.05s
# Elapsed duration 193.03497 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718735939.23s
# Elapsed duration 209.954372 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718736163.94s
# Elapsed duration 224.479844 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718736407.39s
# Elapsed duration 243.182828 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718736663.73s
# Elapsed duration 255.989731 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718736938.45s
# Elapsed duration 274.504979 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718737228.56s
# Elapsed duration 289.235831 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718737534.29s
# Elapsed duration 305.373799 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718737856.39s
# Elapsed duration 321.882883 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738193.19s
# Elapsed duration 336.576924 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738549.31s
# Elapsed duration 355.86427 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi552.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738601.53s
# Elapsed duration 51.974753 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738667.34s
# Elapsed duration 65.601232 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738750.17s
# Elapsed duration 82.595752 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738848.22s
# Elapsed duration 97.803506 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718738961.14s
# Elapsed duration 112.695557 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739091.90s
# Elapsed duration 130.531966 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739235.29s
# Elapsed duration 142.368784 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739399.47s
# Elapsed duration 163.93671 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739576.08s
# Elapsed duration 176.345718 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739770.78s
# Elapsed duration 194.49979 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718739981.08s
# Elapsed duration 210.060961 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718740204.62s
# Elapsed duration 223.314501 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718740448.61s
# Elapsed duration 243.707564 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718740704.40s
# Elapsed duration 255.550568 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718740979.35s
# Elapsed duration 274.658196 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718741269.66s
# Elapsed duration 290.020578 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718741575.09s
# Elapsed duration 305.201796 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718741898.74s
# Elapsed duration 323.440226 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742234.81s
# Elapsed duration 335.826255 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742590.34s
# Elapsed duration 355.270679 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi556.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742640.67s
# Elapsed duration 50.107287 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742705.31s
# Elapsed duration 64.410415 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742788.27s
# Elapsed duration 82.698813 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742886.40s
# Elapsed duration 97.89325 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718742997.78s
# Elapsed duration 111.16446 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718743128.28s
# Elapsed duration 130.280532 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718743273.02s
# Elapsed duration 144.487288 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718743437.96s
# Elapsed duration 164.667304 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718743615.25s
# Elapsed duration 177.076307 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718743808.86s
# Elapsed duration 193.309053 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_10
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718744020.63s
# Elapsed duration 211.471034 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_11
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718744244.58s
# Elapsed duration 223.65856 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_12
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718744488.04s
# Elapsed duration 243.166496 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_13
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718744745.03s
# Elapsed duration 256.767977 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_14
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718745019.54s
# Elapsed duration 274.27941 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_15
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718745309.91s
# Elapsed duration 290.050447 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_16
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718745614.35s
# Elapsed duration 304.186892 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_17
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718745936.17s
# Elapsed duration 321.594847 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_18
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746271.95s
# Elapsed duration 335.499364 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_19
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746628.59s
# Elapsed duration 356.424553 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi560.0ns_20
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746680.19s
# Elapsed duration 51.323062 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746745.75s
# Elapsed duration 65.3372 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_2
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746829.26s
# Elapsed duration 83.296311 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_3
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718746927.59s
# Elapsed duration 98.08431 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_4
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747038.75s
# Elapsed duration 110.907797 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_5
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747169.15s
# Elapsed duration 129.319802 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_6
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747313.52s
# Elapsed duration 144.076645 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_7
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747476.09s
# Elapsed duration 162.300975 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_8
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747652.83s
# Elapsed duration 176.481367 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_9
# Progress: [##################################################] 100.0% (n=16/16) --> elapsed time: 1718747847.20s
# Elapsed duration 194.139647 s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0618\2024-06-18_q1t0_tls_cpmg_rabi564.0ns_10
# Progress: [##################                                ] 37.5% (n=6/16) --> elapsed time: 1718747925.09s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 16
#      14 for cd in cd_time_TLS:
#      15     cd = cd.item()
# ---> 16     machine, expt_dataset = Experiment.exp1D.Rabi.TLS_CPMG_Rabi(machine, N_CPMG_sweep, t, qubit_index, TLS_index,
#      17                      n_avg = 10E3, cd_time_qubit = cd_time_qubit, cd_time_TLS = cd)
#
# File ~\QM\QM_Control\ExperimentClass_1D_Rabi.py:2024, in EH_Rabi.TLS_CPMG_Rabi(self, machine, N_CPMG_sweep, tau, qubit_index, TLS_index, pi_over_2_phase, n_avg, cd_time_qubit, cd_time_TLS, to_simulate, simulation_len, final_plot, data_process_method, calibrate_octave)
#    2022 timestamp_created = datetime.datetime.now()
#    2023 job = qm.execute(tls_cpmg_tau)
# -> 2024 results = fetching_tool(job, data_list=["I", "Q", "iteration"], mode="live")
#    2027 # fetch all data
#    2028 I, Q, iteration = results.fetch_all()
#
# File ~\.conda\envs\qm-env\lib\site-packages\qualang_tools\results\results.py:37, in fetching_tool.__init__(self, job, data_list, mode)
#      35 if hasattr(self.res_handles, data):
#      36     self.data_handles.append(self.res_handles.get(data))
# ---> 37     self.data_handles[-1].wait_for_values(1)
#      38 else:
#      39     raise Warning(f"{data} is not saved in the stream processing.")
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\results\base_streaming_result_fetcher.py:190, in BaseStreamingResultFetcher.wait_for_values(self, count, timeout)
#     180 def wait_for_values(self, count: int = 1, timeout: float = float("infinity")) -> None:
#     181     """Wait until we know at least `count` values were processed for this named result
#     182
#     183     Args:
#    (...)
#     188
#     189     """
# --> 190     run_until_with_timeout(
#     191         lambda: self.count_so_far() >= count,
#     192         timeout=timeout,
#     193         timeout_message=f"result {self.name} was not done in time",
#     194     )
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\utils\general_utils.py:44, in run_until_with_timeout(on_iteration_callback, on_complete_callback, timeout, loop_interval, timeout_message)
#      41 if on_iteration_callback():
#      42     return on_complete_callback()
# ---> 44 time.sleep(loop_interval)
#      46 if time.time() >= end:
#      47     raise TimeoutError(timeout_message)
#
# KeyboardInterrupt:
