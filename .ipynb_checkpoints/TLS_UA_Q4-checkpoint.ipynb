# %% [markdown]
# # TLS Experiments of UA Q4

# %%
from qm.qua import *
from qm import QuantumMachinesManager, SimulationConfig, LoopbackInterface, generate_qua_script
from qm.octave import *
from configuration import *
from scipy import signal
from qualang_tools.bakery import baking
from qm.octave import QmOctaveConfig
from quam import QuAM

from scipy.optimize import curve_fit
from scipy.signal import savgol_filter
#from qutip import *
from typing import Union
from macros import *
import datetime 
import os
import time
import warnings
import json
import matplotlib.pyplot as plt
import numpy as np
import Labber
import xarray as xr

from ExperimentClass import ExperimentHandle
from AnalysisClass import AnalysisHandle

warnings.filterwarnings("ignore")

qubit_index = 0 # for UA Q4
TLS_index = 0 # for TLS of interest
dc_flux_index = 3 # for dc line
# Out:
# 2024-06-10 17:36:09,017 - qm - INFO     - Starting session: 893b093e-38c4-4fe6-96c6-978e5b3bea02

# %%
Analysis = AnalysisHandle("quam_state_q3.json")
machine = Analysis.get_machine()
Experiment = ExperimentHandle(machine)

# %%
# initialize Labber-controlled hardware
# get values from QDAC first
#machine = Experiment.set_Labber.get_value_from_QDAC(machine)
# set all Labber settings
machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
# set octave to external clock
Experiment.set_octave.set_clock(machine)
# Out:
# 2024-06-10 17:35:54,884 - qm - ERROR    - CONFIG ERROR in key "mixers.q3_mixer_f02" [mixers.corrections.intermediateFrequency.values] : Mixer 'q3_mixer_f02' correction 'FrequencyCorrection(frequency=5.06884662E8, loFrequency=5.397468556E9, correction=CorrectionMatrix(v00=1.0, v01=0.0, v10=0.0, v11=1.0))' has an intermediate frequency greater than 5.0E8
# 2024-06-10 17:35:54,886 - qm - ERROR    - CONFIG ERROR in key "elements.q3" [element.intermediateFrequencyUpperLimit] : Element 'q3' has intermediate frequency greater than 5.0E8 (5.06884662E8)
# ---------------------------------------------------------------------------
# OpenQmException                           Traceback (most recent call last)
# Cell In[47], line 7
#       5 machine = Experiment.set_Labber.set_Labber(machine, qubit_index)
#       6 # set octave to external clock
# ----> 7 Experiment.set_octave.set_clock(machine)
#
# File ~\QM\QM_Control\ExperimentClass_Octave.py:31, in EH_Octave.set_clock(self, machine, external_clock)
#      26 """
#      27 should set the octave clock to external 10MHz. Note this is automatically run at the initialization of ExperimentClass
#      28 :return:
#      29 """
#      30 config = build_config(machine)
# ---> 31 qm = self.qmm.open_qm(config)
#      33 # Clock settings #
#      34 if external_clock:
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\quantum_machines_manager.py:265, in QuantumMachinesManager.open_qm(self, config, close_other_machines, validate_with_protobuf, add_calibration_elements_to_config, use_calibration_data, **kwargs)
#     262     loaded_config = prep_config_for_calibration(loaded_config, self._octave_config, self._caps)
#     264 self._octave_manager.set_octaves_from_qua_config(loaded_config.v1_beta.octaves)
# --> 265 machine_id = self._frontend.open_qm(loaded_config, close_other_machines)
#     267 return QuantumMachine(
#     268     machine_id=machine_id,
#     269     pb_config=loaded_config,
#    (...)
#     274     octave_manager=self._octave_manager,
#     275 )
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\api\base_api.py:28, in connection_error_handle_decorator.<locals>.wrapped(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def wrapped(*args: P.args, **kwargs: P.kwargs) -> Ret:
#      27     try:
# ---> 28         return func(*args, **kwargs)
#      29     except grpclib.exceptions.GRPCError as e:
#      30         if is_debug():
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\api\frontend_api.py:130, in FrontendApi.open_qm(self, config, close_other_machines)
#     122         logger.error(
#     123             f'PHYSICAL CONFIG ERROR in key "{physical_error.path}" [{physical_error.group}] : {physical_error.message}'
#     124         )
#     126     errors = [(item.group, item.path, item.message) for item in response.config_validation_errors] + [
#     127         (item.group, item.path, item.message) for item in response.physical_validation_errors
#     128     ]
# --> 130     raise OpenQmException("Can not open QM. Please see previous errors", errors=errors)
#     132 for warning in response.open_qm_warnings:
#     133     logger.warning(f"Open QM ended with warning {warning.code}: {warning.message}")
#
# OpenQmException: Can not open QM. Please see previous errors

# %%
# set for the qubit
machine.octaves[0].LO_sources[1].LO_frequency = machine.qubits[qubit_index].f_01 + 50e6
machine = Analysis.set_machine(machine)
# octave calibration
machine = Experiment.set_octave.calibration(machine, qubit_index)
# Out:
# ------------------------------------- Octave calibration starts...
# ------------------------------------- Calibrates q3 for (LO, IF) = (5.954 GHz, -50.000 MHz)
# ------------------------------------- Calibrates r3 for (LO, IF) = (6.930 GHz, -50.305 MHz)
# ------------------------------------- Octave calibration finished.

# %% [markdown]
# # TLS Characterizations

# %%
TLS_index = 2

# %% [markdown]
# ## TLS T1 (swap)

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(20,400E3+1,1E4)
machine, expt_dataset = Experiment.exp1D.T1.TLS_T1(machine, tau_sweep_abs, qubit_index, TLS_index,
                   n_avg = 1E4, cd_time_qubit = 25E3, cd_time_TLS = 400E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 258.28s
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 258.84s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_T1_swap

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T1: 78.0 [us]

# %% [markdown]
# # TLS Driving Pulses

# %% [markdown]
# ## set rf_gain for TLS pulse

# %%
machine.octaves[0].LO_sources[1].gain = 10

# %% [markdown]
# ## TLS spectroscopy

# %%
# %matplotlib qt
TLS_freq_sweep = machine.qubits[qubit_index].f_tls[TLS_index] + np.arange(-70E6,30E6+1,0.5E6)
machine, expt_dataset = Experiment.exp1D.Rabi.TLS_freq(machine, TLS_freq_sweep, qubit_index, TLS_index,
                  n_avg = 10E3, cd_time_qubit = 25E3, cd_time_TLS = 400E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 857.06s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_spec_3
# Execution stopped by user!

# %%
TLS_freq = 4949.33E6 + 0E6
machine.qubits[qubit_index].f_tls[TLS_index] = TLS_freq + 0E6
machine = Analysis.set_machine(machine)

# %%
expt_dataset = xr.load_dataset(r'Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_spec_3.nc')

# %%
# %matplotlib inline
TLS_freq = Analysis.exp1D.peak_fit(expt_dataset, method = "Gaussian", data_process_method = 'I')
machine.qubits[qubit_index].f_tls[TLS_index] = TLS_freq + 0E6
# machine.qubits[qubit_index].f_tls[TLS_index] = 5439.35E6 + 0E6 
machine = Analysis.set_machine(machine)
# Out:
# peak frequency:  4954.2 [MHz]

# %% [markdown]
# ## TLS rabi

# %% [markdown]
# change rf gain of octave

# %%
# %matplotlib qt
rabi_duration_sweep = np.arange(16, 220 + 0.1, 8)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Rabi.TLS_rabi_length(machine, rabi_duration_sweep, qubit_index, TLS_index,
                      n_avg = 5E3, cd_time_qubit = 25E3, cd_time_TLS = 400E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 55.89s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_time_rabi_8

# %%
# %matplotlib inline
pi_pulse_length = Analysis.exp1D.rabi_length(expt_dataset, method = "Sine", to_plot = True, data_process_method = 'I')
# Out:
# rabi_pi_pulse: 11.6 [ns]
# pi period: 96.59 [ns]

# %%
0.45 * 108 / 108.19
# Out:
# 0.449209723634347

# %%
machine.qubits[qubit_index].pi_amp_tls[TLS_index]
# Out:
# 0.45

# %%
machine.qubits[qubit_index].pi_amp_tls[TLS_index] = 0.449209723634347
machine.qubits[qubit_index].pi_length_tls[TLS_index] = 108
machine = Analysis.set_machine(machine)

# %% [markdown]
# ## TLS Ramsey

# %%
# %matplotlib qt
ramsey_duration_sweep = np.arange(16, 1000 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.Ramsey.TLS_ramsey(machine, ramsey_duration_sweep, qubit_index, TLS_index,
                       n_avg = 5E3, detuning = 2E6, cd_time_qubit = 25E3, cd_time_TLS = 400E3, live_plot = True, data_process_method = 'I')
# Out:
# Execution stopped by user!#                                  ] 32.5% (n=1627/5000.0) --> elapsed time: 85.91s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_ramsey_60.0) --> elapsed time: 86.09s

# %%
# %matplotlib inline
tls_T2star = Analysis.exp1D.ramsey(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T2*:  1.0 [ns]
# Exponent n =  0.2
# Detuning =  19.0 [MHz]

# %% [markdown]
# As a sanity check, run fft, see if there are multiple peaks

# %%
fft_dataset = Analysis.exp1D.fft(expt_dataset, data_process_method = 'I')

# %% [markdown]
# ## TLS T1 with direct driving

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(20,4000E3+1,10E4)
machine, expt_dataset = Experiment.exp1D.T1.TLS_T1_drive(machine, tau_sweep_abs, qubit_index, TLS_index,
                     n_avg = 1E4, cd_time_qubit = 25E3, cd_time_TLS = 4000E3, live_plot = True, data_process_method = 'I')
# Out:
# Progress: [##################################################] 100.0% (n=10000/10000.0) --> elapsed time: 2390.33s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t1_tls_T1_drive

# %%
# %matplotlib inline
TLS_T1 = Analysis.exp1D.T1(expt_dataset, data_process_method = 'I')
# Out:
# Qubit T1: 1088.5 [us]

# %% [markdown]
# # TLS Dynamical Decoupling

# %% [markdown]
# ## Longer Timescale Decay

# %% [markdown]
# ### echo

# %%
# %matplotlib qt
tau_sweep_abs = np.arange(500, 200E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_echo(machine, tau_sweep_abs, qubit_index, TLS_index, n_avg = 5E3,
                     cd_time_qubit = 20E3, cd_time_TLS = 400E3, live_plot = True)
# Out:
# Execution stopped by user!                                   ] 19.3% (n=965/5000.0) --> elapsed time: 59.68s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t2_tls_echo5000.0) --> elapsed time: 60.31s

# %%
# %matplotlib inline
TLS_T2echo = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau =2)
# Out:
# Qubit T2*:  24.6 [us]
# Exponent n =  6.0

# %% [markdown]
# ### CPMG-2

# %%
# %matplotlib qt
N_CPMG = 2
tau_sweep_abs = np.arange(500, 50E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 5E3, cd_time_qubit = 25E3, cd_time_TLS = 5000E3, live_plot = True)
# Out:
# Execution stopped by user!                                   ] 0.4% (n=18/5000.0) --> elapsed time: 2.06s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t1_tls_cpmg20.0) --> elapsed time: 3.15s

# %%
# %matplotlib inline
TLS_T2dd = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau = 2 * N_CPMG)
# Out:
# Qubit T2*:  33.5 [us]
# Exponent n =  0.7

# %% [markdown]
# ### CPMG-8

# %%
# %matplotlib qt
N_CPMG = 8
tau_sweep_abs = np.arange(500, 200E3 + 0.1, 2E3)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 5E3, cd_time_qubit = 20E3, cd_time_TLS = 150E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 882.13s
# Progress: [##################################################] 100.0% (n=5000/5000.0) --> elapsed time: 882.17s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t1_tls_cpmg8

# %%
# %matplotlib inline
TLS_T2dd = Analysis.exp1D.T2(expt_dataset, data_process_method = 'I', N_tau = 2 * N_CPMG)
# Out:
# Qubit T2*:  30.8 [us]
# Exponent n =  0.0

# %% [markdown]
# ## Shorter Timescale Dynamics

# %% [markdown]
# ### CPMG-4

# %%
# %matplotlib inline
N_CPMG = 4
tau_sweep_abs = np.arange(20, 3E3 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 4E3, cd_time_qubit = 25E3, cd_time_TLS = 5000E3, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 3022.33s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 3022.37s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 3022.41s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 3022.44s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0611\2024-06-11_q3t1_tls_cpmg4

# %%
# %matplotlib inline
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0520\2024-05-20_q1t1_tls_cpmg4.nc")
expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
plt.title(expt_dataset.attrs['long_name'])

# %% [markdown]
# ### CPMG-8

# %%
# %matplotlib inline
N_CPMG = 8
tau_sweep_abs = np.arange(20, 3E3 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 4E3, cd_time_qubit = 25E3, cd_time_TLS = 5000E3, live_plot = False)
# Out:
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 324.08s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 324.11s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 324.15s
# Progress: [##################################################] 100.0% (n=4000/4000.0) --> elapsed time: 324.19s
# ----------saved to Z:\QM_Data_DF5\2024\06\Data_0607\2024-06-07_q1t0_tls_cpmg8_5

# %%
# %matplotlib inline
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\06\Data_0607\2024-06-07_q1t0_tls_cpmg8_3.nc")
expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
plt.title(expt_dataset.attrs['long_name'])
# Out:
# Text(0.5, 1.0, 'TLS CPMG-8')

# %% [markdown]
# ### CPMG-16

# %%
# %matplotlib inline
N_CPMG = 16
tau_sweep_abs = np.arange(20, 6E3 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 200E3, live_plot = False)
# Out:
# Progress: [############                                      ] 24.7% (n=989/4000.0) --> elapsed time: 94.53s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[173], line 4
#       2 N_CPMG = 16
#       3 tau_sweep_abs = np.arange(20, 6E3 + 0.1, 20)  # in units of ns
# ----> 4 machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
#       5                      n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 200E3, live_plot = False)
#
# File ~\QM\QM_Control\ExperimentClass_1D_DD.py:419, in EH_DD.TLS_CPMG(self, machine, tau_sweep_abs, qubit_index, TLS_index, pi_over_2_phase, N_CPMG, n_avg, cd_time_qubit, cd_time_TLS, to_simulate, simulation_len, final_plot, live_plot, data_process_method, calibrate_octave)
#     416 progress_counter(iteration, n_avg, start_time=results.get_start_time())
#     418 # Fetch results
# --> 419 I, Q, iteration = results.fetch_all()
#     420 I = u.demod2volts(I, machine.resonators[qubit_index].readout_pulse_length)
#     421 Q = u.demod2volts(Q, machine.resonators[qubit_index].readout_pulse_length)
#
# File ~\.conda\envs\qm-env\lib\site-packages\qualang_tools\results\results.py:94, in fetching_tool.fetch_all(self)
#      92     self.results = []
#      93     for i in range(len(self.data_handles)):
# ---> 94         self.results.append(self._format(self.data_handles[i].fetch_all()))
#      95 return self.results
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\results\single_streaming_result_fetcher.py:40, in SingleStreamingResultFetcher.fetch_all(self, check_for_errors, flat_struct)
#      24 def fetch_all(
#      25     self, *, check_for_errors: bool = True, flat_struct: bool = False
#      26 ) -> Optional[numpy.typing.NDArray[numpy.generic]]:
#      27     """Fetch a result from the current result stream saved in server memory.
#      28     The result stream is populated by the save() and save_all() statements.
#      29     Note that if save_all() statements are used, calling this function twice
#    (...)
#      38         all result of current result stream
#      39     """
# ---> 40     return self.fetch(0, flat_struct=flat_struct, check_for_errors=check_for_errors)
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\results\single_streaming_result_fetcher.py:68, in SingleStreamingResultFetcher.fetch(self, item, check_for_errors, flat_struct)
#      66 if (isinstance(item, int) and item != 0) or isinstance(item, slice):
#      67     logger.warning("Fetching single result will always return the single value")
# ---> 68 value = self.strict_fetch(0, check_for_errors=check_for_errors, flat_struct=flat_struct)
#      69 if flat_struct:
#      70     if len(value) == 0:
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\results\base_streaming_result_fetcher.py:400, in BaseStreamingResultFetcher.strict_fetch(self, item, check_for_errors, flat_struct)
#     397 if step != 1 and step is not None:
#     398     raise Exception("fetch supports step=1 or None in slices")
# --> 400 header = self._get_named_header(check_for_errors=check_for_errors, flat_struct=flat_struct)
#     402 if stop is None:
#     403     stop = header.count_so_far
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\results\base_streaming_result_fetcher.py:290, in BaseStreamingResultFetcher._get_named_header(self, check_for_errors, flat_struct)
#     289 def _get_named_header(self, check_for_errors: bool = True, flat_struct: bool = False) -> NamedJobResultHeader:
# --> 290     response = self._service.get_named_header(self._job_id, self.name, flat_struct)
#     291     dtype = _parse_dtype(response.simple_d_type)
#     293     if check_for_errors and response.has_execution_errors:
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\api\base_api.py:28, in connection_error_handle_decorator.<locals>.wrapped(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def wrapped(*args: P.args, **kwargs: P.kwargs) -> Ret:
#      27     try:
# ---> 28         return func(*args, **kwargs)
#      29     except grpclib.exceptions.GRPCError as e:
#      30         if is_debug():
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\api\job_result_api.py:50, in JobResultServiceApi.get_named_header(self, job_id, output_name, flat_struct)
#      48 def get_named_header(self, job_id: str, output_name: str, flat_struct: bool) -> GetJobNamedResultHeaderResponse:
#      49     request = GetJobNamedResultHeaderRequest(job_id=job_id, output_name=output_name, flat_format=flat_struct)
# ---> 50     response = run_async(self._stub.get_job_named_result_header(request, timeout=self._timeout))
#      51     return response
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\utils\async_utils.py:38, in run_async(coroutine)
#      37 def run_async(coroutine: Coroutine[Any, Any, T]) -> T:
# ---> 38     return create_future(coroutine).result()
#
# File ~\.conda\envs\qm-env\lib\site-packages\qm\utils\async_utils.py:34, in create_future(coroutine)
#      33 def create_future(coroutine: Coroutine[Any, Any, T]) -> asyncio.Future:  # type: ignore[type-arg]
# ---> 34     return asyncio.run_coroutine_threadsafe(coroutine, loop=EventLoopThread().loop)
#
# File ~\.conda\envs\qm-env\lib\asyncio\tasks.py:935, in run_coroutine_threadsafe(coro, loop)
#     932             future.set_exception(exc)
#     933         raise
# --> 935 loop.call_soon_threadsafe(callback)
#     936 return future
#
# File ~\.conda\envs\qm-env\lib\asyncio\base_events.py:802, in BaseEventLoop.call_soon_threadsafe(self, callback, context, *args)
#     800 if handle._source_traceback:
#     801     del handle._source_traceback[-1]
# --> 802 self._write_to_self()
#     803 return handle
#
# File ~\.conda\envs\qm-env\lib\asyncio\selector_events.py:135, in BaseSelectorEventLoop._write_to_self(self)
#     132     return
#     134 try:
# --> 135     csock.send(b'\0')
#     136 except OSError:
#     137     if self._debug:
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
expt_dataset = xr.load_dataset(r"Z:\QM_Data_DF5\2024\05\Data_0520\2024-05-20_q1t1_tls_cpmg16.nc")
expt_dataset['I'].plot(x=list(expt_dataset.coords.keys())[0], marker = '.')
plt.title(expt_dataset.attrs['long_name'])

# %% [markdown]
# ### CPMG-32

# %%
# %matplotlib inline
N_CPMG = 32
tau_sweep_abs = np.arange(20, 6E3 + 0.1, 20)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 4E3, cd_time_qubit = 20E3, cd_time_TLS = 200E3, live_plot = False)

# %% [markdown]
# ### CPMG-40

# %%
# %matplotlib qt
N_CPMG = 40
tau_sweep_abs = np.arange(16, 1.2E3 + 0.1, 4)  # in units of ns
machine, expt_dataset = Experiment.exp1D.DD.TLS_CPMG(machine, tau_sweep_abs, qubit_index, TLS_index, N_CPMG = N_CPMG,
                     n_avg = 2E3, cd_time_qubit = 25E3, cd_time_TLS = 1500E3, live_plot = True)
# Out:
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 937.50s
# Progress: [##################################################] 100.0% (n=2000/2000.0) --> elapsed time: 937.53s
# ----------saved to Z:\QM_Data_DF5\2024\05\Data_0521\2024-05-21_q1t1_tls_cpmg40
# Execution stopped by user!
